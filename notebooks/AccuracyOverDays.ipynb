# %%
acc= {
'Day 0':60.0,
'Day 1':50.0,
'Day 2':57.0,
'Day 3':60.0,
'Day 4':73.0,
'Day 5':63.0,
'Day 6':70.0,
'Day 7':43.0,
'Day 8':73.0,
'Day 9':67.0,
'Day 10':43.0,
'Day 11':67.0,
'Day 12':83.0,
'Day 13':43.0,
'Day 14':93.0,
'Day 15':57.0,
'Day 16':43.0,
'Day 17':50.0,
'Day 18':33.0,
'Day 19':73.0,
'Day 20':53.0,
'Day 21':60.0,
'Day 22':77.0,
'Day 23':60.0,
'Day 24':47.0,
'Day 25':77.0,
'Day 26':50.0,
'Day 27':50.0,
'Day 28':80.0,
'Day 29':53.0,
'Day 30':63.0,
'Day 31':43.0,
}

# %%
import matplotlib.pyplot as plt
import re

# %%
days = [int(x.replace('Day','')) for x in acc.keys()]

# %%
plt.plot(days,acc.values())
